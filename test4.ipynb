# %% [markdown]
# <a href="https://colab.research.google.com/github/trio16/Think/blob/master/test4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os

if not os.path.exists('thinkdsp.py'):
    # !wget https://github.com/AllenDowney/ThinkDSP/raw/master/code/thinkdsp.py ,
     
  

from thinkdsp import CosSignal, SinSignal

cos_sig = CosSignal(freq=440, amp=1.0, offset=0)
sin_sig = SinSignal(freq=880, amp=0.5, offset=0)

from thinkdsp import decorate

# cos_sig.plot()
# decorate(xlabel='Time (s)')



# sin_sig.plot()
# decorate(xlabel='Time (s)')

# mix = sin_sig + cos_sig
# mix

# mix.plot()
# decorate(xlabel='Time (s)')



wave = mix.make_wave(duration=0.5, start=0, framerate=11025)
wave

from IPython.display import Audio
audio = Audio(data=wave.ys, rate=wave.framerate)
audio



wave.make_audio()

print('Number of samples', len(wave.ys))
print('Timestep in ms', 1 / wave.framerate * 1000)



period = mix.period
segment = wave.segment(start=0, duration=period*3)
period



# segment.plot()
decorate(xlabel='Time (s)')



wave.normalize()
wave.apodize()
# wave.plot()
decorate(xlabel='Time (s)')



wave.write('temp.wav')

from thinkdsp import play_wave

play_wave(filename='temp.wav', player='aplay')

from thinkdsp import read_wave
if not os.path.exists('92002__jcveliz_violin-origional.wav'):
    # !wget https://github.com/AllenDowney/ThinkDSP/raw/master/code/92002__jcveliz__violin-origional.wav
wave = read_wave('92002__jcveliz__violin-origional.wav')

wave.make_audio()



start = 1.2
duration = 0.6
segment = wave.segment(start, duration)
# segment.plot()
decorate(xlabel='Time (s)')

spectrum = segment.make_spectrum()


# spectrum.plot()
# decorate(xlabel='Frequency (Hz)')

# spectrum.plot(high=10000)
# decorate(xlabel='Frequency (Hz)')

spectrum.low_pass(3000)


# spectrum.plot(high=10000)
decorate(xlabel='Frequency (Hz)')

filtered = spectrum.make_wave()
filtered.normalize()


filtered.apodize()
# filtered.plot()
decorate(xlabel='Time (s)')

segment.normalize()
segment.apodize()
segment.plot()
decorate(xlabel='Time (s)')
# segment.make_audio()


filtered.make_audio()
# Out:
# Number of samples 5512
# Timestep in ms 0.09070294784580499
# Writing temp.wav
# --2020-09-18 07:17:24--  https://github.com/AllenDowney/ThinkDSP/raw/master/code/92002__jcveliz__violin-origional.wav
# Resolving github.com (github.com)... 140.82.113.4
# Connecting to github.com (github.com)|140.82.113.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/AllenDowney/ThinkDSP/master/code/92002__jcveliz__violin-origional.wav [following]
# --2020-09-18 07:17:24--  https://raw.githubusercontent.com/AllenDowney/ThinkDSP/master/code/92002__jcveliz__violin-origional.wav
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 441044 (431K) [audio/wav]
# Saving to: ‘92002__jcveliz__violin-origional.wav.17’
#
# 92002__jcveliz__vio 100%[===================>] 430.71K  --.-KB/s    in 0.07s
#
# 2020-09-18 07:17:24 (5.77 MB/s) - ‘92002__jcveliz__violin-origional.wav.17’ saved [441044/441044]
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
#@title Example form fields
#@markdown Forms support many types of fields.

no_type_checking = ''  #@param
string_type = 'example'  #@param {type: "string"}
slider_value = 142  #@param {type: "slider", min: 100, max: 200}
number = 102  #@param {type: "number"}
date = '2010-11-05'  #@param {type: "date"}
pick_me = "monday"  #@param ['monday', 'tuesday', 'wednesday', 'thursday']
select_or_input = "apples" #@param ["apples", "bananas", "oranges"] {allow-input: true}
#@markdown ---
